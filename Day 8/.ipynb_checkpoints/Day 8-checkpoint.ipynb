# %%
input_nmbr = ...

# %%
import numpy as np

# %%
input_string = str(input_nmbr)

# %%
pixel_length = len(input_string) / (25 * 6)

# %%
c= 0
picture = []
for i in range(6):
    row = []
    for j in range(25):
        shift = int(c*pixel_length)
        pixel = input_string[(0+shift):((int(pixel_length))+shift)]
        row.append(pixel)
        c = c+1
    picture.append(row)

# %%
picture
# Out:
# [['2222210222222221220222021222222210222222222222220222212222202222222220220222222220222102222122022202',
#   '2222222222122202222222102222222222210222222202222222222012222222222202221202222222202222222222222222',
#   '2221222222222222222022222222222022220222202202221222222222220222222222201222222222222102222222122222',
#   '2222201222222220222222021222222222222222222222222222222222222222222222220222222221222022222022222212',
#   '2222222222022202222220212222222202202222222222222222222102222222212212220202022222112222222222222212',
#   '2220222221222222222022222222222122220222202212220222222222200222122222220222222222222222222222022222',
#   '2222220222222220221222121222222212222222222222222222212222222222222221220222222221222202222122022212',
#   '2222222222022212222220102222222212212222222202222222222112222222222212222212022222122222222222222222',
#   '2221222220222222222222222222222022200222202222220222222222201222222222210222222222022012222222222222',
# ...

# %%
count1 = []
for i in picture:
    row1 = []
    for j in i:
        pixel_str = str(j)
        count = pixel_str.count('0')
        row1.append(count)
    count1.append(row1)
print(count1)
end = int(len(input_string)/6)
input_string[0:end].count('0')
# Out:
# [[12, 8, 8, 6, 9, 9, 5, 5, 10, 7, 8, 5, 10, 7, 9, 7, 8, 11, 6, 10, 12, 9, 14, 9, 12], [8, 11, 3, 9, 12, 12, 6, 10, 10, 11, 9, 9, 7, 15, 18, 6, 14, 13, 12, 11, 11, 8, 17, 16, 13], [14, 12, 16, 11, 16, 15, 10, 14, 14, 14, 20, 11, 11, 11, 21, 11, 12, 15, 12, 17, 13, 10, 17, 19, 13], [19, 22, 20, 12, 20, 16, 13, 20, 22, 26, 16, 15, 17, 18, 13, 21, 15, 25, 20, 17, 15, 23, 15, 16, 21], [16, 21, 24, 23, 19, 24, 20, 13, 24, 20, 16, 24, 18, 23, 23, 23, 21, 21, 18, 29, 28, 22, 19, 26, 20], [25, 29, 26, 27, 29, 30, 26, 26, 17, 25, 36, 25, 27, 31, 24, 34, 27, 24, 20, 27, 23, 30, 34, 29, 36]]
# 216

# %%
count1 = np.array(count1)
picture = np.array(picture)
argmin = str(int(picture[count1 == count1.min()]))

# %%
nr1 = argmin.count('1')
nr2 = argmin.count('2')
nr1 * nr2
# Out:
# 1230

# %%
nr_1 = 0
nr_2 = 0

for i in picture[argmin]:
    nr_1 = nr_1 + str(i).count('1')
    nr_2 = nr_2 + str(i).count('2')

# %%
nr_1 * nr_2
# Out:
# 392139

# %%
print(nr_1)
print(nr_2)
# Out:
# 187
# 2097

# %%
count1
# Out:
# array([215, 269, 344, 455, 529, 675])

# %%
test = '012222221012222222221102000220220102022222211221221122022012112012201202221'

# %%
pixel_length_test = len(test) / (5 * 5)

# %%
c= 0
testpicture = []
for i in range(5):
    row = []
    for j in range(5):
        shift = int(c*pixel_length_test)
        pixel = test[(0+shift):((int(pixel_length_test))+shift)]
        print([(0+shift),((int(pixel_length_test))+shift)])
        row.append(pixel)
        c = c+1
    testpicture.append(row)
# Out:
# [0, 3]
# [3, 6]
# [6, 9]
# [9, 12]
# [12, 15]
# [15, 18]
# [18, 21]
# [21, 24]
# [24, 27]
# [27, 30]
# [30, 33]
# [33, 36]
# [36, 39]
# [39, 42]
# [42, 45]
# [45, 48]
# [48, 51]
# [51, 54]
# [54, 57]
# [57, 60]
# [60, 63]
# [63, 66]
# [66, 69]
# [69, 72]
# [72, 75]

# %%
testpicture
# Out:
# [['012', '222', '221', '012', '222'],
#  ['222', '221', '102', '000', '220'],
#  ['220', '102', '022', '222', '211'],
#  ['221', '221', '122', '022', '012'],
#  ['112', '012', '201', '202', '221']]

# %%
testcount = []
for i in testpicture:
    row1 = 0
    for j in i:
        pixel_str = str(j)
        count = pixel_str.count('0')
        row1 = row1 + count
    testcount.append(row1)

# %%
testcount
# Out:
# [2, 5, 3, 2, 3]

# %%
pixel_length_test
# Out:
# 3.0

# %%
len(test)
# Out:
# 75
